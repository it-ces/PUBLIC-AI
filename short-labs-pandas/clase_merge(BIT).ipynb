# %%
# %%writefile base1.csv
# cedula, ingreso
# 1,  'mil'
# 2,  'dos'
# 3,  'nueve'
# 4,
# Out:
# Overwriting base1.csv

# %%
# %%writefile base2.csv
# cedula, edad
# 1,  10
# 2,  45
# 4,  3
# 9,  9
# Out:
# Overwriting base2.csv

# %%
import pandas as pd

# %%
df1 = pd.read_csv("base1.csv")
df2 = pd.read_csv("base2.csv")

# %%
df1
# Out:
#    cedula    ingreso
# 0       1      'mil'
# 1       2      'dos'
# 2       3    'nueve'
# 3       4        NaN

# %%
df2
# Out:
#    cedula   edad
# 0       1     10
# 1       2     45
# 2       4      3
# 3       9      9

# %%
df1.merge(df2, on='cedula', how='inner') # inner nos va a hacer merge sobre los individuos que aparecen en ambas bases!
# Out:
#    cedula  ingreso   edad
# 0       1    'mil'     10
# 1       2    'dos'     45
# 2       4      NaN      3

# %%
df1.merge(df2, on='cedula', how='outer') # yo puedo uasr esta información para imputar datos
# Out:
#    cedula    ingreso   edad
# 0       1      'mil'   10.0
# 1       2      'dos'   45.0
# 2       3    'nueve'    NaN
# 3       4        NaN    3.0
# 4       9        NaN    9.0

# %%
# %%writefile base1.csv
# identificacion, ingreso
# 1,  'mil'
# 2,  'dos'
# 3,  'nueve'
# 4,
# Out:
# Overwriting base1.csv

# %%
# %%writefile base2.csv
# cedula, edad
# 1,  10
# 2,  45
# 4,  3
# 9,  9
# Out:
# Overwriting base2.csv

# %%
df1  = pd.read_csv("base1.csv")
df2 = pd.read_csv("base2.csv")

# %%
df1.head()
# Out:
#    identificacion    ingreso
# 0               1      'mil'
# 1               2      'dos'
# 2               3    'nueve'
# 3               4        NaN

# %%
df2.head()
# Out:
#    cedula   edad
# 0       1     10
# 1       2     45
# 2       4      3
# 3       9      9

# %%
df1.merge(df2, left_on='identificacion', right_on='cedula')
# Out:
#    identificacion  ingreso  cedula   edad
# 0               1    'mil'       1     10
# 1               2    'dos'       2     45
# 2               4      NaN       4      3

# %%
# %%writefile base1.csv
# year, dpto, income
# 2010, huila, 'mil'
# 2011, huila, 'mil doscientos'
# 2010, antio, 'tres'
# 2011, antio, 'tres cuatro'
# Out:
# Overwriting base1.csv

# %%
# %%writefile base2.csv
# year, dpto, persons
# 2011, antio, 0
# 2010, huila, 1
# 2010, antio, 100
# 2011, huila, -1
# Out:
# Overwriting base2.csv

# %%
df1 = pd.read_csv("base1.csv")
df2 = pd.read_csv("base2.csv")

# %%
df1.columns
# Out:
# Index(['year', ' dpto', ' income'], dtype='object')

# %%
df2.columns
# Out:
# Index(['year', ' dpto', ' persons'], dtype='object')

# %%
df1.merge(df2, on=['year', ' dpto'], how='inner')
# Out:
#    year    dpto             income   persons
# 0  2010   huila              'mil'         1
# 1  2011   huila   'mil doscientos'        -1
# 2  2010   antio             'tres'       100
# 3  2011   antio      'tres cuatro'         0

# %%
df1.columns
# Out:
# Index(['year', ' dpto', ' income'], dtype='object')

# %%
df2.columns
# Out:
# Index(['year', ' dpto', ' persons'], dtype='object')

# %%
df1.columns = [col.replace(" ", "") for col in df1.columns] # los nuevos nombres son los mismos que antes pero sin espacio

# %%
df2.columns = [var.replace(" ", "") for var in df2.columns]

# %%
df2.columns
# Out:
# Index(['year', 'dpto', 'persons'], dtype='object')

# %%
# %%writefile test-data.csv
# id, mora-mayo, saldo-enero, mora-diciembre, saldo-febrero, mora_diciembre-2021, mora.marzo
# 1, 10, 1, 33, 1, 9, 1
# 2 , 0, 0, 0, 1, 0, 1
# 3, 0 ,1, 0 ,1 , 0, 1
# 4, 1, 1, 1, 1,1
# Out:
# Overwriting test-data.csv

# %%
test = pd.read_csv('test-data.csv')

# %%
test
# Out:
#    id   mora-mayo   saldo-enero   mora-diciembre   saldo-febrero  \
# 0   1          10             1               33               1
# 1   2           0             0                0               1
# 2   3           0             1                0               1
# 3   4           1             1                1               1
#
#     mora_diciembre-2021   mora.marzo
# 0                     9          1.0
# 1                     0          1.0
# 2                     0          1.0
# 3                     1          NaN

# %%
test.columns
# Out:
# Index(['id', ' mora-mayo', ' saldo-enero', ' mora-diciembre', ' saldo-febrero',
#        ' mora_diciembre-2021', ' mora.marzo'],
#       dtype='object')

# %%
test[[' mora-mayo', ' mora-diciembre']]
# Out:
#    mora-mayo  mora-diciembre
# 0         10              33
# 1          0               0
# 2          0               0
# 3          1               1

# %%
import re

# %%
bool(re.search(r'mora', ' '))
# Out:
# False

# %%
cols = []
for var in test.columns:
  if bool(re.search(r'mora', var)):  # en todas las variables donde encuentre la palabra mora va a agregar a cols..
    cols.append(var)

# %%
cols
# Out:
# [' mora-mayo', ' mora-diciembre', ' mora_diciembre-2021', ' mora.marzo']

# %%
test[cols]
# Out:
#    mora-mayo  mora-diciembre  mora_diciembre-2021  mora.marzo
# 0         10              33                    9         1.0
# 1          0               0                    0         1.0
# 2          0               0                    0         1.0
# 3          1               1                    1         NaN

# %%
# %%writefile basemayo.csv
# id, mora
# 1, 10
# 2, 0
# 3, 1
# 4,
# Out:
# Overwriting basemayo.csv

# %%
# %%writefile basejunio.csv
# id, mora
# 1, 0
# 2, 1
# 3, 0
# 4, 0
# Out:
# Overwriting basejunio.csv

# %%
df1 = pd.read_csv("basemayo.csv")
df2 = pd.read_csv("basejunio.csv")

# %%
df1.merge(df2, on='id')
# Out:
#    id   mora_x   mora_y
# 0   1     10.0        0
# 1   2      0.0        1
# 2   3      1.0        0
# 3   4      NaN        0

# %%
# %%writefile basemayo.csv
# id, mora , tipo_de_credito
# 1, 10, digital
# 2, 0,  productivo
# 3, 1, digital
# 4, , digital
# Out:
# Overwriting basemayo.csv

# %%
# %%writefile basejunio.csv
# id, mora, tipo_de_credito, another
# 1, 0 , digital , '-'
# 2, 1 , productivo, '-'
# 3, 0, digital, '-'
# 4, 0 , digital, '-'
# Out:
# Overwriting basejunio.csv

# %%
df1 = pd.read_csv("basemayo.csv")
df2 = pd.read_csv("basejunio.csv")

# %%
display(df1)
display(df2)
# Out:
#    id  mora   tipo_de_credito
# 0   1     10          digital
# 1   2      0       productivo
# 2   3      1          digital
# 3   4                 digital
#    id   mora  tipo_de_credito  another
# 0   1      0         digital       '-'
# 1   2      1       productivo      '-'
# 2   3      0          digital      '-'
# 3   4      0          digital      '-'

# %%
df1.merge(df2, on='id')
# Out:
#    id  mora   tipo_de_credito_x   mora  tipo_de_credito_y  another
# 0   1     10            digital      0           digital       '-'
# 1   2      0         productivo      1         productivo      '-'
# 2   3      1            digital      0            digital      '-'
# 3   4                   digital      0            digital      '-'

# %%
df1.columns
# Out:
# Index(['id', ' mora ', ' tipo_de_credito'], dtype='object')

# %%
df2.columns
# Out:
# Index(['id', ' mora', ' tipo_de_credito', ' another'], dtype='object')

# %%
df1.columns = [col.replace(" ","") for col in df1.columns]
df2.columns = [col.replace(" ","") for col in df2.columns]

# %%
full=df1.merge(df2, on='id', how='inner', suffixes=(None, 'to_remove'))

# %%
full
# Out:
#    id mora tipo_de_credito  morato_remove tipo_de_creditoto_remove another
# 0   1   10         digital              0                 digital      '-'
# 1   2    0      productivo              1               productivo     '-'
# 2   3    1         digital              0                  digital     '-'
# 3   4              digital              0                  digital     '-'

# %%
duplicates =  [var for var in full.columns if 'to_remove' in var ]
duplicates
full.drop(columns=duplicates) # estoy borrando las columnas duplicadas en full # muy importante
# Out:
#    id mora tipo_de_credito another
# 0   1   10         digital     '-'
# 1   2    0      productivo     '-'
# 2   3    1         digital     '-'
# 3   4              digital     '-'

# %%
## how='outer'
df1.merge(df2, on='id', how='outer')
# Out:
#    id mora_x tipo_de_credito_x  mora_y tipo_de_credito_y another
# 0   1     10           digital       0          digital      '-'
# 1   2      0        productivo       1        productivo     '-'
# 2   3      1           digital       0           digital     '-'
# 3   4                  digital       0           digital     '-'

# %%
# %%writefile basemayo.csv
# id, mora , tipo_de_credito
# 1, 10, digital
# 2, 0,  productivo
# 3, 1, digital
# 4, , digital
# Out:
# Overwriting basemayo.csv

# %%
# %%writefile basejunio.csv
# id, mora, tipo_de_credito, another
# 1, 0 , digital , '-'
# 2, 1 , productivo, '-'
# 3, 0, digital, '-'
# 4, 0 , digital, '-'
# 9, -1, sistecre, '-'
# Out:
# Overwriting basejunio.csv

# %%
df1 = pd.read_csv("basemayo.csv")
df2= pd.read_csv("basejunio.csv")

# %%
df1
# Out:
#    id  mora   tipo_de_credito
# 0   1     10          digital
# 1   2      0       productivo
# 2   3      1          digital
# 3   4                 digital

# %%
df2
# Out:
#    id   mora  tipo_de_credito  another
# 0   1      0         digital       '-'
# 1   2      1       productivo      '-'
# 2   3      0          digital      '-'
# 3   4      0          digital      '-'
# 4   9     -1         sistecre      '-'

# %%
df1.merge(df2, on='id', how='outer')
# Out:
#    id  mora   tipo_de_credito_x   mora  tipo_de_credito_y  another
# 0   1     10            digital      0           digital       '-'
# 1   2      0         productivo      1         productivo      '-'
# 2   3      1            digital      0            digital      '-'
# 3   4                   digital      0            digital      '-'
# 4   9    NaN                NaN     -1           sistecre      '-'

# %%
set(['a','b', 'c', 'l']) - set(['a', 'b', ]) # que elementos le faltan a derecho para ser izquierdo
# Out:
# {'c', 'l'}

# %%
# que elementos le faltan a mayo para ser como junio!!

# %%
df1['id'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
df2['id'].unique()
# Out:
# array([1, 2, 3, 4, 9])

# %%
set(df2['id'].unique()) - set(df1['id'].unique())
# Out:
# {9}

# %%
df2[df2['id'].isin({9})]
# Out:
#    id   mora  tipo_de_credito  another
# 4   9     -1         sistecre      '-'

# %%
pd.concat([df1, df2])
# Out:
#    id  mora   tipo_de_credito   mora  another
# 0   1     10          digital    NaN      NaN
# 1   2      0       productivo    NaN      NaN
# 2   3      1          digital    NaN      NaN
# 3   4                 digital    NaN      NaN
# 0   1    NaN         digital     0.0      '-'
# 1   2    NaN       productivo    1.0      '-'
# 2   3    NaN          digital    0.0      '-'
# 3   4    NaN          digital    0.0      '-'
# 4   9    NaN         sistecre   -1.0      '-'

# %%
df1.append(df2[df2['id'].isin({9})]) # esta ## OJOOOO para hacer un append el nombre de las columnas debe  ser igualitoooooob
# depreciated
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-46f796dd5795> in <cell line: 1>()
# ----> 1 df1.append(df2[df2['id'].isin({9})]) # esta ## OJOOOO para hacer un append el nombre de las columnas debe  ser igualitoooooob
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# TAREA ARREGLAR LOS NOMBRES Y HACER EL APPEND..
