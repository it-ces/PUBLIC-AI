# %%
#Iván andrés Trujillo Abella
#ivantrujillo1229@gmail.com

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://github.com/it-ces/PUBLIC-AI/blob/main/short-labs-pandas/BIT_lab_duplicates.ipynb)

# %%
import pandas as pd

data = {'var1':['A', 'b', 'A', 'C', 'C', 'C', 'A']}

# %%
data = pd.DataFrame(data)

# %%
data['var1'].duplicated().sum()
# Out:
# 4

# %%
data[data['var1'].duplicated()]
# Out:
#   var1
# 2    A
# 4    C
# 5    C
# 6    A

# %%
data[data['var1'].duplicated(keep=False)] # could be very important...
# Out:
#   var1
# 0    A
# 2    A
# 3    C
# 4    C
# 5    C
# 6    A
