# %%
# ivan trujillo abella
# ivantrujillo1229@gmail.com

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/it-ces/Datasets/refs/heads/main/wbd_small_data_change_names.csv'

# %%
df = pd.read_csv(url)

# %% [markdown]
# # rename:
# * name_of_country_wbd - name
# * Gross_Domestic_Product_2025_USD_millions - gdp
# * Population_estimated_2025_millions population

# %%
df.rename(columns={'Gross_Domestic_Product_2025_USD_millions':'gdp'})
# Out:
#   name_of_country_wbd        gdp  Population_estimated_2025_millions
# 0            Colombia        390                                53.4
# 1           Argentina        640                                46.6
# 2               Chile        340                                19.9
# 3            Paraguay         48                                 7.0
# 4              Brazil  2,330,000                               216.4
# 5              Mexico  1,930,000                               131.9
# 6                Peru        290                                34.7
# 7             Uruguay         82                                 3.5
# 8             Bolivia         52                                12.7

# %%
df.columns
# Out:
# Index(['name_of_country_wbd', 'Gross_Domestic_Product_2025_USD_millions',
#        'Population_estimated_2025_millions'],
#       dtype='object')

# %%
df.rename(columns={'Gross_Domestic_Product_2025_USD_millions':'gdp'}, inplace=True)

# %%
df.columns
# Out:
# Index(['name_of_country_wbd', 'gdp', 'Population_estimated_2025_millions'], dtype='object')

# %%
df.rename({'name_of_country_wbd':'name',
           'Population_estimated_2025_millions':'pop'},
          axis= 1, inplace=True)
