# %%
#Iván Andrés Trujillo Abella
#ivantrujillo1229@gmail.com

# %%
import pandas as pd
df = pd.read_excel("basepibs.xlsx", sheet_name="Cuadro 2", usecols='A:S', skiprows=9, skipfooter=4)

# %%
df[2005].sum()
# Out:
# 1032691.3483158948

# %%
ls
# Out:
# basepibs.xlsx  sample_data/

# %%
df.columns
# Out:
# Index(['Código Departamento (DIVIPOLA)',                  'DEPARTAMENTOS',
#                                    2005,                             2006,
#                                    2007,                             2008,
#                                    2009,                             2010,
#                                    2011,                             2012,
#                                    2013,                             2014,
#                                    2015,                             2016,
#                                    2017,                             2018,
#                                    2019,                          '2020p',
#                                 '2021p'],
#       dtype='object')

# %%
## TAREA COMO SACO A COLOMBIA DE LA BASE!

# %%
df['pib-colombia-2005']= df[2005].sum()  # not is a FCO crate the c...

# %%
df['sharing-2005'] = df[2005]/df['pib-colombia-2005']

# %%
for year in range(2005, 2020):
  df[str(year)+'-share'] = df[year]/df[year].sum()

# %%
df.columns
# Out:
# Index(['Código Departamento (DIVIPOLA)',                  'DEPARTAMENTOS',
#                                    2005,                             2006,
#                                    2007,                             2008,
#                                    2009,                             2010,
#                                    2011,                             2012,
#                                    2013,                             2014,
#                                    2015,                             2016,
#                                    2017,                             2018,
#                                    2019,                          '2020p',
#                                 '2021p',              'pib-colombia-2005',
#                          'sharing-2005',                     '2005-share',
#                            '2006-share',                     '2007-share',
# ...

# %%
df.head()
# Out:
#    Código Departamento (DIVIPOLA) DEPARTAMENTOS           2005           2006  \
# 0                             NaN      COLOMBIA  514853.000000  549435.000000
# 1                            91.0      Amazonas     413.007446     432.519609
# 2                             5.0     Antioquia   73922.532786   79223.681846
# 3                            81.0        Arauca    5044.233001    5101.916075
# 4                             8.0     Atlántico   22121.967036   23862.690923
#
#             2007           2008           2009           2010           2011  \
# 0  586457.000000  605713.000000  612616.000000  640151.000000  684628.000000
# 1     442.275690     456.909813     469.917921     486.178057     500.812179
# 2   84784.032893   86215.889649   85660.010691   88492.495048   95753.273585
# 3    5537.575079    5778.933204    5768.307374    5284.073150    5077.628465
# 4   26106.040803   26748.374341   26735.527670   26632.754304   28126.179779
#
# ...

# %%
df[df["DEPARTAMENTOS"]!='COLOMBIA']
# Out:
#     Código Departamento (DIVIPOLA)  \
# 1                             91.0
# 2                              5.0
# 3                             81.0
# 4                              8.0
# 5                             11.0
# 6                             13.0
# 7                             15.0
# 8                             17.0
# 9                             18.0
# 10                            85.0
# 11                            19.0
# 12                            20.0
# 13                            27.0
# 14                            23.0
# 15                            25.0
# 16                            94.0
# 17                            95.0
# 18                            41.0
# 19                            44.0
# 20                            47.0
# 21                            50.0
# 22                            52.0
# 23                            54.0
# 24                            86.0
# 25                            63.0
# ...

# %%
df_ = pd.DataFrame({'var1':[100,56,30,102], 'var2':['A','B','A','B']})

# %%
df_
# Out:
#    var1 var2
# 0   100    A
# 1    56    B
# 2    30    A
# 3   102    B

# %%
df_['mean-var1'] = df_['var1'].mean()

# %%
df_['under-over'] = df_['var1']>df_['mean-var1']

# %%
df_
# Out:
#    var1 var2  mean-var1  under-over
# 0   100    A       72.0        True
# 1    56    B       72.0       False
# 2    30    A       72.0       False
# 3   102    B       72.0        True

# %%
# Filter-> me interesa saber de los A quienes están por encima del promedio con var1
df_
# Out:
#    var1 var2  mean-var1  under-over
# 0   100    A       72.0        True
# 1    56    B       72.0       False
# 2    30    A       72.0       False
# 3   102    B       72.0        True

# %%
df_['indicator'] = df_['var1']  >  df_['var1'].mean()

# %%
df_
# Out:
#    var1 var2  mean-var1  under-over  indicator
# 0   100    A       72.0        True       True
# 1    56    B       72.0       False      False
# 2    30    A       72.0       False      False
# 3   102    B       72.0        True       True

# %%
df_[(df_['indicator']==True) & (df_['var2']=='A')]
# Out:
#    var1 var2  mean-var1  under-over  indicator
# 0   100    A       72.0        True       True

# %% [markdown]
# # quiero saber para el 2005 que departamentos tienen una participación en el PIB total superior a la media de participación
#
#
# 13%

# %%
df = df[df['DEPARTAMENTOS']!='COLOMBIA']

# %%
df['share-2005'] = (df[2005]/df[2005].sum())*100
# Out:
# <ipython-input-91-5d029e8f03f3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['share-2005'] = (df[2005]/df[2005].sum())*100

# %%
df['share-2005']
# Out:
# 1      0.079756
# 2     14.275214
# 3      0.974094
# 4      4.271983
# 5     26.111403
# 6      3.646992
# 7      2.523776
# 8      1.817415
# 9      0.403265
# 10     1.931803
# 11     1.592545
# 12     1.752714
# 13     0.488684
# 14     1.997357
# 15     5.771377
# 16     0.040312
# 17     0.100949
# 18     1.899898
# 19     1.194381
# 20     1.363728
# 21     1.907432
# 22     1.518302
# 23     1.554557
# 24     0.288090
# 25     0.812025
# 26     1.755983
# 27     0.157068
# 28     6.474648
# 29     0.778893
# 30     2.412238
# 31    10.000638
# 32     0.026523
# 33     0.075956
# Name: share-2005, dtype: float64

# %%
df['share-2005'].mean()
# Out:
# 3.0303030303030307

# %%
df['indicator']= df['share-2005']> df['share-2005'].mean()
# Out:
# <ipython-input-97-1d1f53da4efa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['indicator']= df['share-2005']> df['share-2005'].mean()

# %%
df['indicator'].value_counts()
# Out:
# False    26
# True      7
# Name: indicator, dtype: int64

# %%
df[df['indicator']==True]
# Out:
#     Código Departamento (DIVIPOLA)    DEPARTAMENTOS           2005  \
# 2                              5.0        Antioquia   73922.532786
# 4                              8.0        Atlántico   22121.967036
# 5                             11.0      Bogotá D.C.  135214.860000
# 6                             13.0          Bolívar   18885.522452
# 15                            25.0     Cundinamarca   29886.401533
# 28                            68.0        Santander   33528.209787
# 31                            76.0  Valle del Cauca   51787.137693
#
#              2006           2007           2008           2009           2010  \
# 2    79223.681846   84784.032893   86215.889649   85660.010691   88492.495048
# 4    23862.690923   26106.040803   26748.374341   26735.527670   26632.754304
# 5   144141.327225  153258.830699  158292.934352  161609.204236  167408.945355
# 6    20196.091190   21861.251037   22152.015746   22106.628084   23076.789358
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 1 to 33
# Data columns (total 38 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Código Departamento (DIVIPOLA)  33 non-null     float64
#  1   DEPARTAMENTOS                   33 non-null     object
#  2   2005                            33 non-null     float64
#  3   2006                            33 non-null     float64
#  4   2007                            33 non-null     float64
#  5   2008                            33 non-null     float64
#  6   2009                            33 non-null     float64
#  7   2010                            33 non-null     float64
#  8   2011                            33 non-null     float64
#  9   2012                            33 non-null     float64
#  10  2013                            33 non-null     float64
#  11  2014                            33 non-null     float64
# ...

# %%
df[df['share-2005'] > df['share-2005'].mean()]
# Out:
#     Código Departamento (DIVIPOLA)    DEPARTAMENTOS           2005  \
# 2                              5.0        Antioquia   73922.532786
# 4                              8.0        Atlántico   22121.967036
# 5                             11.0      Bogotá D.C.  135214.860000
# 6                             13.0          Bolívar   18885.522452
# 15                            25.0     Cundinamarca   29886.401533
# 28                            68.0        Santander   33528.209787
# 31                            76.0  Valle del Cauca   51787.137693
#
#              2006           2007           2008           2009           2010  \
# 2    79223.681846   84784.032893   86215.889649   85660.010691   88492.495048
# 4    23862.690923   26106.040803   26748.374341   26735.527670   26632.754304
# 5   144141.327225  153258.830699  158292.934352  161609.204236  167408.945355
# 6    20196.091190   21861.251037   22152.015746   22106.628084   23076.789358
# ...

# %%
# TAREA.... 1
# Out:
#     Código Departamento (DIVIPOLA)  \
# 1                             91.0
# 2                              5.0
# 3                             81.0
# 4                              8.0
# 5                             11.0
# 6                             13.0
# 7                             15.0
# 8                             17.0
# 9                             18.0
# 10                            85.0
# 11                            19.0
# 12                            20.0
# 13                            27.0
# 14                            23.0
# 15                            25.0
# 16                            94.0
# 17                            95.0
# 18                            41.0
# 19                            44.0
# 20                            47.0
# 21                            50.0
# 22                            52.0
# 23                            54.0
# 24                            86.0
# 25                            63.0
# ...

# %%
def vf(vp,r,n):
  return vp*((1+r)**n)

# %%
vf(1,1,1)
# Out:
# 2

# %%
vf(100,0.22,12)
# Out:
# 1087.2213398722909

# %%
vf()
