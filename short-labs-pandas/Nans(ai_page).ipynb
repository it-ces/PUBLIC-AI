# %%
# Iván Andrés Trujillo Abella
# ivantrujillo1229@gmail.com

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/it-ces/Datasets/refs/heads/main/stock_price_dataset.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#   product  price  cost  quantity_available
# 0       A     10   NaN                 NaN
# 1       B     30  10.0                 NaN
# 2       C     40  12.0                10.0
# 3       D     13   NaN               330.0
# 4       E      1   0.4                 NaN
# 5       F     11   8.0               400.0
# 6       G     33  22.0                33.0
# 7       H      1   0.1               111.0

# %%
df.isna().sum()
# Out:
# product               0
# price                 0
# cost                  2
# quantity_available    3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# product               0
# price                 0
# cost                  2
# quantity_available    3
# dtype: int64

# %%
df['product'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['cost'].notna().sum()
# Out:
# np.int64(6)

# %%
df['price'].notna().sum()
# Out:
# np.int64(8)

# %% [markdown]
# this information is very imporant.
