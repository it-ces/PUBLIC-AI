# %%
import pandas as pd

# %%
df = pd.DataFrame({'var1':['a', 'b', 'a', 'd'],
                   'var2':[10,11,12,14] })

# %%
df
# Out:
#   var1  var2
# 0    a    10
# 1    b    11
# 2    a    12
# 3    d    14

# %%
df2 = df

# %%
df2
# Out:
#   var1  var2
# 0    a    10
# 1    b    11
# 2    a    12
# 3    d    14

# %%
df2.drop([1,3], axis=0, inplace=True)

# %%
df
# Out:
#   var1  var2
# 0    a    10
# 2    a    12

# %%
test = pd.DataFrame({'var1':[10,22,33,45], 'var2':[True, False, True, False]})

# %%
test2 = test.copy()

# %%
test2.drop([0,1], axis=0) # axis  = 0 filas
# Out:
#    var1   var2
# 2    33   True
# 3    45  False

# %%
test.drop(['var1'], axis=1) # axis = 1 columns
# Out:
#     var2
# 0   True
# 1  False
# 2   True
# 3  False

# %%
testing = pd.DataFrame({'var1':[10,22,34,45],
                        'var2': [True, False,True, False]
                        }, index=['soache', 'yeimi', 'andy', 'yeli'])

# %%
testing.drop(['andy','soache'], axis=0, inplace=True)

# %%
testing = testing.drop(['var2'], axis=1)

# %%
testing
# Out:
#        var1
# yeimi    22
# yeli     45

# %%
df2 = pd.DataFrame({'VARIABLE':[True, False, True, False],
                   'name var 2' :[10,20,30,54],
                    'Unamed var 3':['A', 'b', 'C','D']})

# %%
df2 = df2.drop(columns=['Unamed var 3'])

# %%
df2.drop([3], axis=0, inplace=True)

# %%
# HINT: si la función, el método tiene disp.. el argumento o la opción
#inplace usenla...!
# Out:
#    VARIABLE  name var 2
# 0      True          10
# 1     False          20
# 2      True          30

# %%
df2['indicator'] = df2['name var 2'] > df2['name var 2'].mean()

# %%
df2['new'] = df2['name var 2'].mean()

# %%
df2
# Out:
#    VARIABLE  name var 2  indicator   new
# 0      True          10      False  20.0
# 1     False          20      False  20.0
# 2      True          30       True  20.0

# %%
data = {'var1':['bankrupt', 'no-bankrupt', 'bankrupt', 'no-bankrupt'],
        'X1':[10,20,30,40],
        'sector':['Financial', 'Software', 'Software', 'Financial']}

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#           var1  X1     sector
# 0     bankrupt  10  Financial
# 1  no-bankrupt  20   Software
# 2     bankrupt  30   Software
# 3  no-bankrupt  40  Financial

# %%
data['var1']=='bankrupt'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# Name: var1, dtype: bool

# %%
data[pd.Series((True, False, True, False))]
# Out:
#        var1  X1     sector
# 0  bankrupt  10  Financial
# 2  bankrupt  30   Software

# %%
data[data['var1']=='bankrupt']
# Out:
#        var1  X1     sector
# 0  bankrupt  10  Financial
# 2  bankrupt  30   Software

# %%
data[data['sector']=='Financial']
# Out:
#           var1  X1     sector
# 0     bankrupt  10  Financial
# 3  no-bankrupt  40  Financial

# %%
data['sector'].value_counts()
# Out:
# Financial    2
# Software     2
# Name: sector, dtype: int64

# %%
data
# Out:
#           var1  X1     sector
# 0     bankrupt  10  Financial
# 1  no-bankrupt  20   Software
# 2     bankrupt  30   Software
# 3  no-bankrupt  40  Financial

# %%
df_financial = data[data['sector']=='Financial']

# %%
df_financial.shape
# Out:
# (2, 3)

# %%
data['sector']=='Software'
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: sector, dtype: bool

# %%
data['var1']=='bankrupt'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# Name: var1, dtype: bool

# %%
data[(data['var1']=='bankrupt') & (data['sector']=='Software')]
# Out:
#        var1  X1    sector
# 2  bankrupt  30  Software

# %%
data.columns = ['default', 'utility/asset', 'sector']

# %%
data.columns = [col_name.upper() for col_name in data.columns] # list-comprenhesion

# %%
data
# Out:
#        DEFAULT  UTILITY/ASSET     SECTOR
# 0     bankrupt             10  Financial
# 1  no-bankrupt             20   Software
# 2     bankrupt             30   Software
# 3  no-bankrupt             40  Financial

# %%
data['SECTOR']  = data['SECTOR'].replace('Software', 'IT')

# %%
type(data['DEFAULT']) # dataframe
# Out:
# pandas.core.series.Series

# %%
len(dir(pd.Series()))
# Out:
# <ipython-input-108-21db34178b6c>:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   len(dir(pd.Series()))
# 419

# %%
len(dir(pd.DataFrame()))
# Out:
# 435

# %%
type(data[['DEFAULT']])
# Out:
# pandas.core.frame.DataFrame
