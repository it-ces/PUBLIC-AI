# %%
#iván Andrés Trujillo Abella
#ivantrujillo1229@gmail.com

# %%
# creating a dataframe
import pandas as pd
df = pd.DataFrame({'A': ['Country A', 'Country B', 'Country C'],
                   'B': ['HIC', 'LIC', 'HIC'],
                   'C': [40, 10, 70]})

# %%
df
# Out:
#            A    B   C
# 0  Country A  HIC  40
# 1  Country B  LIC  10
# 2  Country C  HIC  70

# %%
df.pivot(index='A', columns='B', values=['C'])
# Out:
#               C
# B           HIC   LIC
# A
# Country A  40.0   NaN
# Country B   NaN  10.0
# Country C  70.0   NaN

# %%
df.pivot(index='B', columns='A', values=['C'])
# Out:
#             C
# A   Country A Country B Country C
# B
# HIC      40.0       NaN      70.0
# LIC       NaN      10.0       NaN

# %%
df = pd.DataFrame(

 {'country': ['A','A', 'B','B', 'B', 'C','C','C','C'],
      'year':[2010, 2011, 2010, 2011, 2012, 2010, 2011, 2012, 2013],
      'gdp': [1,1.7, 1.9, 6.7, 6.6, 7, 10.1, 10.73, 11.3,],
      'lifeexp': [60, 61, 61, 70, 72, 74, 80, 81, 85,]}
)

# %%
df
# Out:
#   country  year    gdp  lifeexp
# 0       A  2010   1.00       60
# 1       A  2011   1.70       61
# 2       B  2010   1.90       61
# 3       B  2011   6.70       70
# 4       B  2012   6.60       72
# 5       C  2010   7.00       74
# 6       C  2011  10.10       80
# 7       C  2012  10.73       81
# 8       C  2013  11.30       85

# %%
df_ = df.pivot(index='country', columns='year', values=['gdp', 'lifeexp'])

# %%
df_
# Out:
#          gdp                    lifeexp
# year    2010  2011   2012  2013    2010  2011  2012  2013
# country
# A        1.0   1.7    NaN   NaN    60.0  61.0   NaN   NaN
# B        1.9   6.7   6.60   NaN    61.0  70.0  72.0   NaN
# C        7.0  10.1  10.73  11.3    74.0  80.0  81.0  85.0

# %%
df_.columns  = [col[0] + str(col[1]) for col in df_.columns]

# %%
df_.head()
# Out:
#          gdp2010  gdp2011  gdp2012  gdp2013  lifeexp2010  lifeexp2011  \
# country
# A            1.0      1.7      NaN      NaN         60.0         61.0
# B            1.9      6.7     6.60      NaN         61.0         70.0
# C            7.0     10.1    10.73     11.3         74.0         80.0
#
#          lifeexp2012  lifeexp2013
# country
# A                NaN          NaN
# B               72.0          NaN
# C               81.0         85.0

# %%
df
# Out:
#   country  year    gdp  lifeexp
# 0       A  2010   1.00       60
# 1       A  2011   1.70       61
# 2       B  2010   1.90       61
# 3       B  2011   6.70       70
# 4       B  2012   6.60       72
# 5       C  2010   7.00       74
# 6       C  2011  10.10       80
# 7       C  2012  10.73       81
# 8       C  2013  11.30       85

# %%
df_wide = df.set_index(['country', 'year']).unstack(level=-1)

# %%
df_wide
# Out:
#          gdp                    lifeexp
# year    2010  2011   2012  2013    2010  2011  2012  2013
# country
# A        1.0   1.7    NaN   NaN    60.0  61.0   NaN   NaN
# B        1.9   6.7   6.60   NaN    61.0  70.0  72.0   NaN
# C        7.0  10.1  10.73  11.3    74.0  80.0  81.0  85.0

# %%
df_.reset_index(inplace=True)

# %%
df_
pd.wide_to_long(df_, stubnames=['gdp', 'lifeexp'],
                i ='country',
                j='year')
# Out:
#                 gdp  lifeexp
# country year
# A       2010   1.00     60.0
# B       2010   1.90     61.0
# C       2010   7.00     74.0
# A       2011   1.70     61.0
# B       2011   6.70     70.0
# C       2011  10.10     80.0
# A       2012    NaN      NaN
# B       2012   6.60     72.0
# C       2012  10.73     81.0
# A       2013    NaN      NaN
# B       2013    NaN      NaN
# C       2013  11.30     85.0
